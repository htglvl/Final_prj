# %%
import win32gui, win32ui, win32con, win32api, win32com.client

import cv2 
from screen_input_old import *
from config import *
from PIL import ImageGrab
import numpy as np

# %%
{'provider': {'name': 'Counter-Strike: Global Offensive', 'appid': 730, 'version': 14012, 'steamid': '76561198852936807', 'timestamp': 1717768240}, 'player': {'steamid': '76561198852936807', 'name': 'thvl', 'observer_slot': 15, 'team': 'T', 'activity': 'playing', 'state': {'health': 0, 'armor': 0, 'helmet': False, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 0, 'round_killhs': 0, 'equip_value': 1200}, 'match_stats': {'kills': 0, 'assists': 0, 'deaths': 14, 'mvps': 0, 'score': 0}, 'weapons': {}}, 'map': {'mode': 'deathmatch', 'name': 'de_dust2', 'phase': 'live', 'round': 0, 'team_ct': {'score': 0, 'consecutive_round_losses': 0, 'timeouts_remaining': 1, 'matches_won_this_series': 0}, 'team_t': {'score': 0, 'consecutive_round_losses': 0, 'timeouts_remaining': 1, 'matches_won_this_series': 0}, 'num_matches_to_win_series': 0}, 'round': {'phase': 'live'}, 'previously': {'player': {'state': {'health': 51, 'armor': 90, 'helmet': True}, 'match_stats': {'deaths': 13}, 'weapons': {'weapon_0': {'name': 'weapon_knife_t', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_glock', 'paintkit': 'cu_glock18_corroden', 'type': 'Pistol', 'ammo_clip': 20, 'ammo_clip_max': 20, 'ammo_reserve': 120, 'state': 'active'}}}}}

{'provider': 
 {'name': 'Counter-Strike: Global Offensive', 'appid': 730, 'version': 14012, 'steamid': '76561198852936807', 'timestamp': 1717768243}, 
    'player': {'steamid': '76561198852936807', 'name': 'thvl', 'observer_slot': 15, 'team': 'T', 'activity': 'playing', 'state': {'health': 100, 'armor': 100, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 0, 'round_killhs': 0, 'equip_value': 1200}, 'match_stats': {'kills': 0, 'assists': 0, 'deaths': 14, 'mvps': 0, 'score': 0}, 'weapons': {'weapon_0': {'name': 'weapon_knife_t', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_glock', 'paintkit': 'cu_glock18_corroden', 'type': 'Pistol', 'ammo_clip': 20, 'ammo_clip_max': 20, 'ammo_reserve': 120, 'state': 'active'}}},
    'map': {'mode': 'deathmatch', 'name': 'de_dust2', 'phase': 'live', 'round': 0, 'team_ct': {'score': 0, 'consecutive_round_losses': 0, 'timeouts_remaining': 1, 'matches_won_this_series': 0}, 'team_t': {'score': 0, 'consecutive_round_losses': 0, 'timeouts_remaining': 1, 'matches_won_this_series': 0}, 'num_matches_to_win_series': 0}, 
    'round': {'phase': 'live'}, 'previously': {'player': {'state': {'health': 0, 'armor': 0, 'helmet': False}}}, 'added': {'player': {'weapons': {'weapon_0': True, 'weapon_1': True}}}}

# %%
127.0.0.1 - - [07/Jun/2024 21:26:18] "POST / HTTP/1.1" 200 -
{'provider': 
    {'name': 'Counter-Strike: Global Offensive', 'appid': 730, 'version': 14012, 'steamid': '76561198852936807', 'timestamp': 1717770379}, 
 'player': 
    {'steamid': '76561199012769908', 'name': '31', 'observer_slot': 5, 'team': 'T', 'activity': 'playing', 'state': {'health': 73, 'armor': 97, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 0, 'round_killhs': 0, 'round_totaldmg': 0, 'equip_value': 4400}, 'match_stats': {'kills': 35, 'assists': 2, 'deaths': 38, 'mvps': 0, 'score': 385}, 'weapons': {'weapon_0': {'name': 'weapon_knife_t', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_ak47', 'paintkit': 'cu_ak47_anubis', 'type': 'Rifle', 'ammo_clip': 0, 'ammo_clip_max': 30, 'ammo_reserve': 90, 'state': 'holstered'}, 'weapon_2': {'name': 'weapon_deagle', 'paintkit': 'cu_deagle_aureus', 'type': 'Pistol', 'ammo_clip': 7, 'ammo_clip_max': 7, 'ammo_reserve': 35, 'state': 'active'}}, 'spectarget': '76561199012769908', 'position': '608.86, 700.76, 1.02', 'forward': '0.65, 0.75, -0.11'}, 
 'map': 
    {'mode': 'deathmatch', 'name': 'de_dust2', 'phase': 'live', 'round': 0, 'team_ct': {'score': 0, 'consecutive_round_losses': 0, 'timeouts_remaining': 1, 'matches_won_this_series': 0}, 'team_t': {'score': 0, 'consecutive_round_losses': 0, 'timeouts_remaining': 1, 'matches_won_this_series': 0}, 'num_matches_to_win_series': 0}, 'round': {'phase': 'live'}, 'grenades': {}, 'allplayers': {'76561199657542562': {'name': 'WAZ2T3PW0', 'observer_slot': 1, 'team': 'T', 'match_stats': {'kills': 44, 'assists': 3, 'deaths': 25, 'mvps': 0, 'score': 502}, 'position': '831.11, 919.40, 0.17', 'forward': '-0.78, -0.62, -0.06', 'state': {'health': 24, 'armor': 85, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 2, 'round_killhs': 2, 'round_totaldmg': 227, 'equip_value': 4400}, 'weapons': {'weapon_0': {'name': 'weapon_knife_t', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_ak47', 'paintkit': 'default', 'type': 'Rifle', 'ammo_clip': 15, 'ammo_clip_max': 30, 'ammo_reserve': 90, 'state': 'active'}, 'weapon_2': {'name': 'weapon_deagle', 'paintkit': 'default', 'type': 'Pistol', 'ammo_clip': 7, 'ammo_clip_max': 7, 'ammo_reserve': 35, 'state': 'holstered'}}}, '76561199657202771': {'name': 'F1XJ44R', 'observer_slot': 3, 'team': 'T', 'match_stats': {'kills': 41, 'assists': 1, 'deaths': 25, 'mvps': 0, 'score': 456}, 'position': '-179.62, 1409.99, -0.28', 'forward': '-0.90, -0.30, -0.32', 'state': {'health': 75, 'armor': 99, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 2, 'round_killhs': 1, 'round_totaldmg': 116, 'equip_value': 3900}, 'weapons': {'weapon_0': {'name': 'weapon_knife_t', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_glock', 'paintkit': 'default', 'type': 'Pistol', 'ammo_clip': 20, 'ammo_clip_max': 20, 'ammo_reserve': 120, 'state': 'holstered'}, 'weapon_2': {'name': 'weapon_ak47', 'paintkit': 'default', 'type': 'Rifle', 'ammo_clip': 20, 'ammo_clip_max': 30, 'ammo_reserve': 90, 'state': 'active'}}}, '76561199645543817': {'name': 'tbuoxojy', 'observer_slot': 10, 'team': 'T', 'match_stats': {'kills': 20, 'assists': 4, 'deaths': 28, 'mvps': 0, 'score': 239}, 'position': '-1853.55, 1126.80, 32.55', 'forward': '0.93, 0.36, -0.01', 'state': {'health': 100, 'armor': 100, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 0, 'round_killhs': 0, 'round_totaldmg': 0, 'equip_value': 4000}, 'weapons': {'weapon_0': {'name': 'weapon_knife_t', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_ak47', 'paintkit': 'default', 'type': 'Rifle', 'ammo_clip': 30, 'ammo_clip_max': 30, 'ammo_reserve': 90, 'state': 'active'}, 'weapon_2': {'name': 'weapon_elite', 'paintkit': 'default', 'type': 'Pistol', 'ammo_clip': 30, 'ammo_clip_max': 30, 'ammo_reserve': 120, 'state': 'holstered'}}}, '76561199651990893': {'name': '备乐', 'observer_slot': 4, 'team': 'T', 'match_stats': {'kills': 38, 'assists': 3, 'deaths': 31, 'mvps': 0, 'score': 437}, 'position': '-422.41, 1123.55, -87.21', 'forward': '0.00, 1.00, -0.01', 'state': {'health': 0, 'armor': 0, 'helmet': False, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 0, 'round_killhs': 0, 'round_totaldmg': 0, 'equip_value': 3900}, 'weapons': {}}, '76561199012769908': {'name': '31', 'observer_slot': 5, 'team': 'T', 'match_stats': {'kills': 35, 'assists': 2, 'deaths': 38, 'mvps': 0, 'score': 385}, 'position': '608.86, 700.76, 1.02', 'forward': '0.65, 0.75, -0.11', 'state': {'health': 73, 'armor': 97, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 0, 'round_killhs': 0, 'round_totaldmg': 0, 'equip_value': 4400}, 'weapons': {'weapon_0': {'name': 'weapon_knife_t', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_ak47', 'paintkit': 'cu_ak47_anubis', 'type': 'Rifle', 'ammo_clip': 0, 'ammo_clip_max': 30, 'ammo_reserve': 90, 'state': 'holstered'}, 'weapon_2': {'name': 'weapon_deagle', 'paintkit': 'cu_deagle_aureus', 'type': 'Pistol', 'ammo_clip': 7, 'ammo_clip_max': 7, 'ammo_reserve': 35, 'state': 'active'}}}, '76561199414096719': {'name': 'Dcccc', 'observer_slot': 14, 'team': 'CT', 'match_stats': {'kills': 10, 'assists': 0, 'deaths': 28, 'mvps': 0, 'score': 120}, 'position': '-2128.38, -855.87, 118.48', 'forward': '1.00, -0.01, -0.00', 'state': {'health': 100, 'armor': 100, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 0, 'round_killhs': 0, 'round_totaldmg': 0, 'equip_value': 3400}, 'weapons': {'weapon_0': {'name': 'weapon_knife_m9_bayonet', 'paintkit': 'sp_dapple', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_ssg08', 'paintkit': 'sp_zebracam_red', 'type': 'SniperRifle', 'ammo_clip': 10, 'ammo_clip_max': 10, 'ammo_reserve': 90, 'state': 'holstered'}, 'weapon_2': {'name': 'weapon_deagle', 'paintkit': 'cu_deag_printstream', 'type': 'Pistol', 'ammo_clip': 6, 'ammo_clip_max': 7, 'ammo_reserve': 35, 'state': 'active'}}}, '76561199353528949': {'name': '百花落无痕', 'observer_slot': 13, 'team': 'T', 'match_stats': {'kills': 12, 'assists': 7, 'deaths': 38, 'mvps': 0, 'score': 176}, 'position': '-1916.81, 1868.82, 0.38', 'forward': '-0.26, -0.97, -0.01', 'state': {'health': 100, 'armor': 100, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 1, 'round_killhs': 0, 'round_totaldmg': 26, 'equip_value': 4400}, 'weapons': {'weapon_0': {'name': 'weapon_knife_t', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_ak47', 'paintkit': 'default', 'type': 'Rifle', 'ammo_clip': 19, 'ammo_clip_max': 30, 'ammo_reserve': 90, 'state': 'active'}, 'weapon_2': {'name': 'weapon_deagle', 'paintkit': 'default', 'type': 'Pistol', 'ammo_clip': 7, 'ammo_clip_max': 7, 'ammo_reserve': 35, 'state': 'holstered'}}}, '76561199547174000': {'name': 'xx', 'observer_slot': 0, 'team': 'CT', 'match_stats': {'kills': 47, 'assists': 7, 'deaths': 28, 'mvps': 0, 'score': 585}, 'position': '-1676.37, 2615.33, 6.36', 'forward': '-0.41, -0.91, -0.02', 'state': {'health': 100, 'armor': 100, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 0, 'round_killhs': 0, 'round_totaldmg': 0, 'equip_value': 4600}, 'weapons': {'weapon_0': {'name': 'weapon_knife', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_m4a1_silencer', 'paintkit': 'cu_m4a1s_printstream', 'type': 'Rifle', 'ammo_clip': 20, 'ammo_clip_max': 20, 'ammo_reserve': 80, 'state': 'active'}, 'weapon_2': {'name': 'weapon_deagle', 'paintkit': 'default', 'type': 'Pistol', 'ammo_clip': 7, 'ammo_clip_max': 7, 'ammo_reserve': 35, 'state': 'holstered'}}}, '76561199535947128': {'name': 'verniphoce1988', 'observer_slot': 9, 'team': 'CT', 'match_stats': {'kills': 21, 'assists': 2, 'deaths': 33, 'mvps': 0, 'score': 243}, 'position': '-1925.71, 45.43, -0.28', 'forward': '-0.22, -0.97, 0.12', 'state': {'health': 100, 'armor': 100, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 0, 'round_killhs': 0, 'round_totaldmg': 0, 'equip_value': 5000}, 'weapons': {'weapon_0': {'name': 'weapon_knife', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_aug', 'paintkit': 'default', 'type': 'Rifle', 'ammo_clip': 30, 'ammo_clip_max': 30, 'ammo_reserve': 90, 'state': 'active'}, 'weapon_2': {'name': 'weapon_deagle', 'paintkit': 'default', 'type': 'Pistol', 'ammo_clip': 7, 'ammo_clip_max': 7, 'ammo_reserve': 35, 'state': 'holstered'}}}, '76561199225299727': {'name': '我要当快攻小子', 'observer_slot': 7, 'team': 'CT', 'match_stats': {'kills': 22, 'assists': 5, 'deaths': 35, 'mvps': 0, 'score': 272}, 'position': '485.12, -304.28, 7.22', 'forward': '-0.75, 0.66, -0.12', 'state': {'health': 74, 'armor': 97, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 0, 'round_killhs': 0, 'round_totaldmg': 0, 'equip_value': 4200}, 'weapons': {'weapon_0': {'name': 'weapon_knife', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_usp_silencer', 'paintkit': 'default', 'type': 'Pistol', 'ammo_clip': 12, 'ammo_clip_max': 12, 'ammo_reserve': 24, 'state': 'holstered'}, 'weapon_2': {'name': 'weapon_m4a1', 'paintkit': 'hy_ddpat_urb', 'type': 'Rifle', 'ammo_clip': 21, 'ammo_clip_max': 30, 'ammo_reserve': 90, 'state': 'active'}}}, '76561198219427001': {'name': 'Happy⚡Ann', 'observer_slot': 2, 'team': 'T', 'match_stats': {'kills': 41, 'assists': 5, 'deaths': 31, 'mvps': 0, 'score': 487}, 'position': '-792.58, -860.68, 117.61', 'forward': '0.91, 0.40, -0.09', 'state': {'health': 100, 'armor': 100, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 1, 'round_killhs': 1, 'round_totaldmg': 126, 'equip_value': 4600}, 'weapons': {'weapon_0': {'name': 'weapon_knife_t', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_ak47', 'paintkit': 'aq_ak47_cartel', 'type': 'Rifle', 'ammo_clip': 24, 'ammo_clip_max': 30, 'ammo_reserve': 90, 'state': 'active'}, 'weapon_2': {'name': 'weapon_deagle', 'paintkit': 'cu_deag_trigger_discipline', 'type': 'Pistol', 'ammo_clip': 7, 'ammo_clip_max': 7, 'ammo_reserve': 35, 'state': 'holstered'}, 'weapon_3': {'name': 'weapon_taser', 'paintkit': 'default', 'ammo_clip': 1, 'ammo_clip_max': 1, 'ammo_reserve': 0, 'state': 'holstered'}}}, '76561198128740015': {'name': 'TBS', 'observer_slot': 6, 'team': 'CT', 'match_stats': {'kills': 29, 'assists': 0, 'deaths': 19, 'mvps': 0, 'score': 319}, 'position': '-144.75, 2079.88, -124.64', 'forward': '-0.64, 0.76, -0.00', 'state': {'health': 100, 'armor': 100, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 1, 'round_killhs': 1, 'round_totaldmg': 100, 'equip_value': 4100}, 'weapons': {'weapon_0': {'name': 'weapon_knife', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_hkp2000', 'paintkit': 'default', 'type': 'Pistol', 'ammo_clip': 13, 'ammo_clip_max': 13, 'ammo_reserve': 52, 'state': 'holstered'}, 'weapon_2': {'name': 'weapon_m4a1_silencer', 'paintkit': 'default', 'type': 'Rifle', 'ammo_clip': 15, 'ammo_clip_max': 20, 'ammo_reserve': 80, 'state': 'active'}}}, '76561198892958982': {'name': 'Lin_Ruimeng', 'observer_slot': 12, 'team': 'CT', 'match_stats': {'kills': 15, 'assists': 2, 'deaths': 34, 'mvps': 0, 'score': 197}, 'position': '1420.50, 2968.50, 119.83', 'forward': '-0.90, -0.43, -0.06', 'state': {'health': 100, 'armor': 100, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 0, 'round_killhs': 0, 'round_totaldmg': 0, 'equip_value': 4100}, 'weapons': {'weapon_0': {'name': 'weapon_knife', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_usp_silencer', 'paintkit': 'cu_usp_to_hell', 'type': 'Pistol', 'ammo_clip': 12, 'ammo_clip_max': 12, 'ammo_reserve': 24, 'state': 'holstered'}, 'weapon_2': {'name': 'weapon_m4a1_silencer', 'paintkit': 'gs_m4a1s_milspec', 'type': 'Rifle', 'ammo_clip': 20, 'ammo_clip_max': 20, 'ammo_reserve': 80, 'state': 'active'}}}, '76561199008125453': {'name': '橘飞飞', 'observer_slot': 8, 'team': 'CT', 'match_stats': {'kills': 23, 'assists': 3, 'deaths': 17, 'mvps': 0, 'score': 265}, 'position': '-419.68, 2405.45, -93.96', 'forward': '0.44, -0.90, -0.06', 'state': {'health': 0, 'armor': 0, 'helmet': False, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 2, 'round_killhs': 0, 'round_totaldmg': 200, 'equip_value': 5950}, 'weapons': {}}, '76561199177344191': {'name': '分崩离析fblx', 'observer_slot': 11, 'team': 'T', 'match_stats': {'kills': 19, 'assists': 1, 'deaths': 4, 'mvps': 0, 'score': 237}, 'position': '-1112.71, 1146.84, -41.22', 'forward': '-1.00, 0.00, 0.08', 'state': {'health': 46, 'armor': 92, 'helmet': True, 'flashed': 0, 'smoked': 0, 'burning': 0, 'money': 0, 'round_kills': 6, 'round_killhs': 3, 'round_totaldmg': 483, 'equip_value': 4200}, 'weapons': {'weapon_0': {'name': 'weapon_knife_t', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_ak47', 'paintkit': 'cu_ak47_mastery', 'type': 'Rifle', 'ammo_clip': 30, 'ammo_clip_max': 30, 'ammo_reserve': 90, 'state': 'active'}, 'weapon_2': {'name': 'weapon_tec9', 'paintkit': 'am_tec_9_sea_salt', 'type': 'Pistol', 'ammo_clip': 10, 'ammo_clip_max': 18, 'ammo_reserve': 90, 'state': 'holstered'}, 'weapon_3': {'name': 'weapon_healthshot', 'paintkit': 'default', 'type': 'StackableItem', 'ammo_reserve': 1, 'state': 'holstered'}}}}, 'phase_countdowns': {'phase': 'live', 'phase_ends_in': '145.1'}, 'previously': {'player': {'position': '606.75, 604.43, 1.08', 'forward': '0.57, 0.81, -0.15'}, 'allplayers': {'76561199657542562': {'position': '923.00, 980.26, 0.22', 'forward': '-0.82, -0.57, -0.09'}, '76561199657202771': {'position': '-43.10, 1371.25, 0.24', 'forward': '-0.78, -0.53, -0.32'}, '76561199645543817': {'forward': '-0.92, 0.39, -0.01'}, '76561199012769908': {'position': '606.75, 604.43, 1.08', 'forward': '0.57, 0.81, -0.15'}, '76561199414096719': {'position': '-2129.24, -863.05, 118.66', 'forward': '1.00, -0.07, 0.01', 'weapons': {'weapon_2': {'ammo_clip': 7}}}, '76561199353528949': {'position': '-1798.07, 1927.11, -0.33', 'forward': '-0.69, -0.69, -0.23'}, '76561199547174000': {'position': '-1644.48, 2678.12, 8.12', 'forward': '-0.99, -0.16, -0.00'}, '76561199535947128': {'position': '-1846.00, 110.82, 2.86', 'forward': '-0.24, -0.97, 0.11'}, '76561199225299727': {'position': '482.89, -305.00, 7.70', 'forward': '0.18, 0.98, -0.03', 'state': {'health': 100, 'armor': 100}, 'weapons': {'weapon_2': {'ammo_clip': 28}}}, '76561198219427001': {'position': '-884.10, -920.63, 121.03', 'forward': '0.91, 0.41, -0.08', 'state': {'round_totaldmg': 100}, 'weapons': {'weapon_1': {'ammo_clip': 25}}}, '76561198128740015': {'match_stats': {'kills': 28, 'score': 308}, 'position': '-115.72, 2096.05, -125.28', 'forward': '-0.64, 0.77, 0.03', 'state': {'round_kills': 0, 'round_killhs': 0, 'round_totaldmg': 0}, 'weapons': {'weapon_2': {'ammo_clip': 20}}}, '76561198892958982': {'forward': '-0.17, -0.99, 0.00'}, '76561199008125453': {'match_stats': {'deaths': 16}, 'position': '-436.47, 2404.83, -94.08', 'forward': '-0.02, -1.00, 0.01', 'state': {'health': 100, 'armor': 100, 'helmet': True}, 'weapons': {'weapon_0': {'name': 'weapon_knife', 'paintkit': 'default', 'type': 'Knife', 'state': 'holstered'}, 'weapon_1': {'name': 'weapon_usp_silencer', 'paintkit': 'cu_usp_flashback', 'type': 'Pistol', 'ammo_clip': 12, 'ammo_clip_max': 12, 'ammo_reserve': 24, 'state': 'holstered'}, 'weapon_2': {'name': 'weapon_awp', 'paintkit': 'hy_technowar_rwb', 'type': 'SniperRifle', 'ammo_clip': 3, 'ammo_clip_max': 5, 'ammo_reserve': 30, 'state': 'active'}}}, '76561199177344191': {'position': '-1142.77, 1097.06, -16.49', 'forward': '-1.00, 0.07, 0.06'}}, 'phase_countdowns': {'phase_ends_in': '145.8'}}}
# Out:
#   Cell In[1], line 1
#     127.0.0.1 - - [07/Jun/2024 21:26:18] "POST / HTTP/1.1" 200 -
#                    ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
import cv2
import numpy as np
from ctypes import windll
import win32gui
import win32ui


def capture_win_alt(window_name: str):
    # Adapted from https://stackoverflow.com/questions/19695214/screenshot-of-inactive-window-printwindow-win32gui

    windll.user32.SetProcessDPIAware()
    hwnd = win32gui.FindWindow(None, window_name)

    left, top, right, bottom = win32gui.GetClientRect(hwnd)
    w = right - left
    h = bottom - top
    bar_height = 35
    offset_height_top = 135 
    offset_height_bottom = 135 


    offset_sides = 100 # ignore this many pixels on sides, 
    width =  w - 2*offset_sides
    height = h - offset_height_top-offset_height_bottom

    hwnd_dc = win32gui.GetWindowDC(hwnd)
    mfc_dc = win32ui.CreateDCFromHandle(hwnd_dc)
    save_dc = mfc_dc.CreateCompatibleDC()
    bitmap = win32ui.CreateBitmap()
    bitmap.CreateCompatibleBitmap(mfc_dc, w, h)
    save_dc.SelectObject(bitmap)

    # If Special K is running, this number is 3. If not, 1
    result = windll.user32.PrintWindow(hwnd, save_dc.GetSafeHdc(), 3)

    bmpinfo = bitmap.GetInfo()
    bmpstr = bitmap.GetBitmapBits(True)

    img = np.frombuffer(bmpstr, dtype=np.uint8).reshape((bmpinfo["bmHeight"], bmpinfo["bmWidth"], 4))
    img = np.ascontiguousarray(img)[..., :-1]  # make image C_CONTIGUOUS and drop alpha channel
    img = img[bar_height+offset_height_top:height + bar_height+offset_height_top, offset_sides:width + offset_sides]

    if not result:  # result should be 1
        win32gui.DeleteObject(bitmap.GetHandle())
        save_dc.DeleteDC()
        mfc_dc.DeleteDC()
        win32gui.ReleaseDC(hwnd, hwnd_dc)
        img = np.zeros((width, height, 3), dtype=np.uint8)
        print(f"Unable to acquire screenshot! Result: {result}")

    return img


# def main():

#     WINDOW_NAME = "Counter-Strike 2"
#     while cv2.waitKey(1) != ord('q'):
#         screenshot = capture_win_alt(WINDOW_NAME)
#         cv2.imshow('Computer Vision', screenshot)
# main()

# %%
def capture_window(window_title):
    # Find the window handle
    hwnd = win32gui.FindWindow(None, 'Counter-Strike 2')
    if not hwnd:
        print("Window not found")
        return None
    
    # Get the dimensions of the window
    rect = win32gui.GetClientRect(hwnd)
    left, top, right, bottom = rect
    width = right - left
    height = bottom - top
    
    # Get the device context for the window
    hwindc = win32gui.GetWindowDC(hwnd)
    srcdc = win32ui.CreateDCFromHandle(hwindc)
    memdc = srcdc.CreateCompatibleDC()
    
    # Create a bitmap compatible with the window DC
    bmp = win32ui.CreateBitmap()
    bmp.CreateCompatibleBitmap(srcdc, width, height)
    
    # Select the bitmap into the memory DC
    memdc.SelectObject(bmp)
    
    # Copy the window contents into the memory DC
    memdc.BitBlt((0, 0), (width, height), srcdc, (0, 0), win32con.SRCCOPY)
    
    # Convert the bitmap to a format compatible with OpenCV
    bmpinfo = bmp.GetInfo()
    bmpstr = bmp.GetBitmapBits(True)
    img = np.frombuffer(bmpstr, dtype=np.uint8).reshape((height, width, 4))
    
    # Release device contexts
    memdc.DeleteDC()
    win32gui.ReleaseDC(hwnd, hwindc)
    
    # Convert BGRA to BGR (if needed)
    img = cv2.cvtColor(img, cv2.COLOR_BGRA2BGR)
    
    return img

# Example usage
window_title = "Calculator"  # Replace with the title of the window you want to capture
captured_image = capture_window(window_title)
if captured_image is not None:
    cv2.imshow("Captured Window", captured_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
def grab_window(hwin, game_resolution=(1024,768), SHOW_IMAGE=False):
    '''
    -- Inputs --

    hwin
    this is the HWND id of the cs go window
    we play in windowed rather than full screen mode
    e.g. https://docs.microsoft.com/en-us/windows/win32/api/winuser/nf-winuser-getforegroundwindow

    game_resolution=(1024,768)
    is the windowed resolution of the game
    I think could get away with game_resolution=(640,480)
    and should be quicker to grab from
    but for now, during development, I like to see the game in reasonable
    size

    SHOW_IMAGE
    whether to display the image. probably a bad idea to 
    do that here except for testing
    better to use cv2.imshow('img',img) outside the funcion

    -- Outputs --
    currently this function returns img_small
    img is the raw capture image, in BGR
    img_small is a low res image, with the thought of
    using this as input to a NN

    '''

    # we used to try to get the resolution automatically
    # but this didn't seem that reliable for some reason
    # left,top,right,bottom = win32gui.GetWindowRect(hwin)
    # width = right - left 
    # height = bottom - top


    bar_height =0 # 35 # height of header bar


    # how much of top and bottom of image to ignore
    # (reasoning we don't need the entire screen)
    # much more efficient not to grab it in the first place
    # rather than crop out later
    # this stage can be a bit of a bottle neck
    offset_height_top = 0# 135 
    offset_height_bottom = 0 # 135 


    offset_sides = 0 #100 # ignore this many pixels on sides, 
    width =  game_resolution[0] - 2*offset_sides
    height = game_resolution[1] - offset_height_top-offset_height_bottom


    hwindc = win32gui.GetWindowDC(hwin)
    srcdc = win32ui.CreateDCFromHandle(hwindc)
    memdc = srcdc.CreateCompatibleDC()
    bmp = win32ui.CreateBitmap()
    bmp.CreateCompatibleBitmap(srcdc, width, height)
    memdc.SelectObject(bmp)

    memdc.BitBlt((0, 0), (width, height), srcdc, (offset_sides, bar_height+offset_height_top), win32con.SRCCOPY)
    signedIntsArray = bmp.GetBitmapBits(True)
    img = np.frombuffer(signedIntsArray, dtype='uint8')
    img.shape = (height,width,4)

    srcdc.DeleteDC()
    memdc.DeleteDC()
    win32gui.ReleaseDC(hwin, hwindc)
    win32gui.DeleteObject(bmp.GetHandle())

    img = cv2.cvtColor(img, cv2.COLOR_BGRA2BGR)
    # img = cv2.cvtColor(img, cv2.COLOR_BGRA2GRAY)
    if IS_CONTRAST:
        contrast = 1.5
        brightness = 1.0
        img = cv2.addWeighted(img, contrast, img, 0, brightness)
    

    img_small = cv2.resize(img, csgo_img_dimension[::-1])


    if SHOW_IMAGE:

        target_width = 800
        scale = target_width / img_small.shape[1] # how much to magnify
        dim = (target_width,int(img_small.shape[0] * scale))
        resized = cv2.resize(img_small, dim, interpolation = cv2.INTER_AREA)
        cv2.imshow('resized',resized) 
        if cv2.waitKey(1) & 0xFF == ord('q'):
            cv2.destroyAllWindows()

    return img_small
    # return img, img_small

# %%
n_grabs=20000
hwin = win32gui.FindWindow(None,'Counter-Strike 2')
for i in range(n_grabs):
    # img_small = grab_window(hwin, game_resolution=(1024,768), SHOW_IMAGE=False)
    img_small = capture_win_alt("Counter-Strike 2")
    if True:
        # because we use a shrunk image for input into the NN
        # we kind of want to make it larger so we can see what's happening
        # of course it's lossy compared to the original game
        target_width = 800
        scale = target_width / img_small.shape[1] # how much to magnify
        dim = (target_width,int(img_small.shape[0] * scale))
        resized = cv2.resize(img_small, dim, interpolation = cv2.INTER_AREA)
        cv2.imshow('resized',img_small) 


    if cv2.waitKey(1) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
        break

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 5
#       2 hwin = win32gui.FindWindow(None,'Counter-Strike 2')
#       3 for i in range(n_grabs):
#       4     # img_small = grab_window(hwin, game_resolution=(1024,768), SHOW_IMAGE=False)
# ----> 5     img_small = capture_win_alt("Counter-Strike 2")
#       6     if True:
#       7         # because we use a shrunk image for input into the NN
#       8         # we kind of want to make it larger so we can see what's happening
#       9         # of course it's lossy compared to the original game
#      10         target_width = 800
#
# Cell In[1], line 39, in capture_win_alt(window_name)
#      36 bmpinfo = bitmap.GetInfo()
#      37 bmpstr = bitmap.GetBitmapBits(True)
# ---> 39 img = np.frombuffer(bmpstr, dtype=np.uint8).reshape((bmpinfo["bmHeight"], bmpinfo["bmWidth"], 4))
# ...

# %%
time_start = time.time()
n_grabs=20000
hwin = win32gui.FindWindow(None,'Counter-Strike 2')
for i in range(n_grabs):
    # shell = win32com.client.Dispatch("WScript.Shell")
    # shell.SendKeys('%')
    # win32gui.SetForegroundWindow(hwin)
    win32gui.MoveWindow(hwin, 0, 0, 1024,768, True)
    dimensions = win32gui.GetWindowRect(hwin)

    image = ImageGrab.grab(dimensions)
    open_cv_image = np.array(image)
    # Convert RGB to BGR
    img_small = open_cv_image[:, :, ::-1]

    #img_small = grab_window(hwin, game_resolution=(1024,768), SHOW_IMAGE=True)
    print(type(image))
    if True:
        # because we use a shrunk image for input into the NN
        # we kind of want to make it larger so we can see what's happening
        # of course it's lossy compared to the original game
        target_width = 800
        scale = target_width / img_small.shape[1] # how much to magnify
        dim = (target_width,int(img_small.shape[0] * scale))
        resized = cv2.resize(img_small, dim, interpolation = cv2.INTER_AREA)


    if cv2.waitKey(1) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
        break
# Out:
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# <class 'PIL.Image.Image'>
# ...

# %%
fps_capture_test()
# Out:
# avg_time 7e-05
# fps 13609.15
